# %% [markdown]
# <a href="https://colab.research.google.com/github/doaa450/Stock-price-prediction-using-GAN/blob/master/%D9%86%D8%B5%D9%81_%D9%84%D9%88%D8%BA%D8%A7%D8%B1%D8%AA%D9%8A%D9%85.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
# %matplotlib inline
sns.set_style('whitegrid')
plt.style.use("fivethirtyeight")
sns.set(rc={'figure.figsize': [9, 9]}, font_scale=1.2)

# %%
from sklearn.linear_model import  Ridge

# %%
df=pd.read_excel('/content/1دعاء.xlsx')

# %%
df.head()
# Out:
#    year       y  x1   x2  x3     x4    x5     x6     x7    x8  ...        LX4  \
# 0  1970  783898   3  175  10  58144  4747  10016  65407  4747  ...  10.970678
# 1  1971  921952   4  140  12  60747  5232  60747  65992  5232  ...  11.014473
# 2  1972  926661   3  149  11  64309  5524  64309  70254  5524  ...  11.071455
# 3  1973  882018   3  408  13  65738  5456  65738  71057  5456  ...  11.093432
# 4  1974  936014   4  330  16  63905  5862  63905  69144  5862  ...  11.065153
#
#         LX5        LX6        LX7       LX8       LX9       LX10       LX11  \
# 0  8.465268   9.211939  11.088385  8.465268  7.565275  12.566847  10.517510
# 1  8.562549  11.014473  11.097289  8.562549  7.673223  12.634509  10.546446
# 2  8.616858  11.071455  11.159873  8.616858  7.709308  12.678595  10.613098
# 3  8.604471  11.093432  11.171238  8.604471  7.751045  12.600396  10.610414
# 4  8.676246  11.065153  11.143947  8.676246  7.776954  12.694751  10.593931
#
#         LX12      LX13
# 0  12.629420  9.154933
# 1  12.813855  9.149741
# 2  12.746042  9.178540
# 3  12.672968  9.168163
# 4  12.764353  9.120853
#
# [5 rows x 29 columns]

# %%
df.columns
# Out:
# Index(['year', 'y', 'x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8', 'x9',
#        'x10', 'x11', 'x12', 'x13', 'LY', 'LX1', 'LX2', 'LX3', 'LX4', 'LX5',
#        'LX6', 'LX7', 'LX8', 'LX9', 'LX10', 'LX11', 'LX12', 'LX13'],
#       dtype='object')

# %% [markdown]
# # Drop Year
# # split data
# # Standarization
# # Build Model
# # Performance Measure

# %%
df.drop('year',axis=1,inplace= True)

# %%
df.head()
# Out:
#         y  x1   x2  x3     x4    x5     x6     x7    x8    x9  ...        LX4  \
# 0  783898   3  175  10  58144  4747  10016  65407  4747  1930  ...  10.970678
# 1  921952   4  140  12  60747  5232  60747  65992  5232  2150  ...  11.014473
# 2  926661   3  149  11  64309  5524  64309  70254  5524  2229  ...  11.071455
# 3  882018   3  408  13  65738  5456  65738  71057  5456  2324  ...  11.093432
# 4  936014   4  330  16  63905  5862  63905  69144  5862  2385  ...  11.065153
#
#         LX5        LX6        LX7       LX8       LX9       LX10       LX11  \
# 0  8.465268   9.211939  11.088385  8.465268  7.565275  12.566847  10.517510
# 1  8.562549  11.014473  11.097289  8.562549  7.673223  12.634509  10.546446
# 2  8.616858  11.071455  11.159873  8.616858  7.709308  12.678595  10.613098
# 3  8.604471  11.093432  11.171238  8.604471  7.751045  12.600396  10.610414
# 4  8.676246  11.065153  11.143947  8.676246  7.776954  12.694751  10.593931
#
#         LX12      LX13
# 0  12.629420  9.154933
# 1  12.813855  9.149741
# 2  12.746042  9.178540
# 3  12.672968  9.168163
# 41   4   652   6  61092  58515  61092  67254  58515  24614  682003  78793
# 42   6   507  10  62406  57987  62406  67512  57987  24825  685503  83190
# 43  10   986   7  67502  58188  67502  73384  58188  25761  683609  83606
# 44  14   598   4  72387  64988  72387  79276  64988  32338  859005  90189
# 45  10   601   5  72755  73103  72755  81204  73103  34534  688927  97316
# 46  11   618   7  65593  72480  65593  72648  72480  33945  681948  94507
# 47   9  1072   9  64350  78650  64350  72575  78650  35492  686880  92395
# 48  11   690   8  65004  85068  65004  73477  85068  40689  681562  92277
# 49  13   563   4  69808  92791  69808  81197  92791  45444  687053  95300
#
#        x12    x13
# 0   305413   9461
# 1   367271   9412
# 2   343191   9687
# 3   319007   9587
# 4   349533   9144
# 5   284000   8422
# 6   369981  10421
# 7   346683  10468
# 8   350541  12658
# 9   360843  10775
# 10  363383  10474
# 11  366312  10251
# 12  347758  10438
# 13  348882  11705
# 14  404153  10336
# 15  399137  13181
# 16  392061  11928
# 17  390027  10381
# 18  396882  11810
# 19  376353  14263
# 20  387131  14698
# 21  388192  11961
# 22  382673  14257
# 23  440076  13862
# 24  427972  13846
# 25  427418  15047
# 26  462988  15812
# 27  477520  16136
# 28  476367  16280
# 29  508833  16576
# 30  579473  16011
# 31  443445  14001
# 32  633587  15837
# 33  566985  16294
# 34  530550  15587
# 35  503450  15276
# 36  299563  14496
# 37  591832  17182
# 38  638109  22402
# 39  733462  25070
# 40  834352  29271
# 41  796499  29126
# 42  885453  32941
# 43  873853  33727
# 44  911296  38025
# 45  921870  44123
# 46  892907  43341
# 47  864446  44577
# 48  837503  45367
# 49  876807  51037

# %%
Y=df.iloc[:,14:15]

# %%
Y
# Out:
#            LY
# 0   13.572034
# 1   13.734248
# 2   13.739343
# 3   13.689968
# 4   13.749386
# 5   13.706347
# 6   13.797374
# 7   13.757036
# 8   13.750169
# 9   13.780197
# 10  13.765497
# 11  13.770668
# 12  13.770221
# 13  13.776499
# 14  13.858939
# 15  13.841226
# 16  13.809578
# 17  13.803838
# 18  13.833259
# 19  13.791152
# 20  13.843548
# 21  13.777923
# 22  13.822713
# 23  13.850065
# 24  13.847246
# 25  13.849987
# 26  13.936295
# 27  13.998340
# 28  13.991628
# 29  14.052159
# 30  14.129985
# 31  13.903390
# 32  14.104256
# 33  14.065079
# 34  14.076834
# 35  14.067580
# 36  13.903902
# 37  14.143810
# 38  14.243437
# 39  14.397947
# 40  14.460420
# 41  14.466880
# 42  14.518971
# 43  14.521733
# 44  14.642093
# 45  14.585760
# 46  14.555579
# 47  14.549538
# 48  14.543894
# 49  14.586829

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=25)

# %%
from sklearn.linear_model import  Ridge

ridge = Ridge(alpha=0.001)
ridge.fit(X_train, y_train)
# Out:
# Ridge(alpha=0.001)

# %%
trainPredict=ridge.predict(X_train)

# %%
testPredict=ridge.predict(X_test)

# %%
#from sklearn.model_selection import TimeSeriesSplit

# %%
#tscv = TimeSeriesSplit(n_splits=3)

# %% [markdown]
# ## RMSE

# %%
import math
from sklearn.metrics import mean_squared_error
trainScore = math.sqrt(mean_squared_error(y_train, trainPredict))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(y_test, testPredict))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 0.01 RMSE
# Test Score: 0.04 RMSE

# %% [markdown]
# ## MAE

# %%
MAE_test=np.mean(np.abs(testPredict-y_test))
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3472: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)

# %%
MAE_test
# Out:
# LY    0.02992
# dtype: float64

# %%
MAE_train=np.mean(np.abs(trainPredict-y_train))
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3472: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)

# %%
MAE_train
# Out:
# LY    0.010944
# dtype: float64

# %% [markdown]
# ## MAPE

# %%
import numpy as np

def mape(actual, pred): 
    actual, pred = np.array(actual), np.array(pred)
    return np.mean(np.abs((actual - pred) / actual)) * 100

# %%
mape(y_test,testPredict)
# Out:
# 0.21178220219615693

# %%
mape(y_train,trainPredict)
# Out:
# 0.07816793009375997

# %%
y_test
# Out:
#            LY
# 36  13.903902
# 46  14.555579
# 7   13.757036
# 41  14.466880
# 17  13.803838
# 14  13.858939
# 34  14.076834
# 33  14.065079
# 45  14.585760
# 39  14.397947
# 48  14.543894
# 40  14.460420
# 2   13.739343
# 27  13.998340
# 11  13.770668

# %%
testPredict.round(2)
# Out:
# array([[13.92],
#        [14.56],
#        [13.72],
#        [14.45],
#        [13.79],
#        [13.76],
#        [14.07],
#        [14.07],
#        [14.59],
#        [14.48],
#        [14.51],
#        [14.52],
#        [13.75],
#        [13.95],
#        [13.77]])

# %%
import statsmodels.api as sm

# %%
 
# performing the regression
# and fitting the model
result = sm.OLS(Y, X).fit()
 
# printing the summary table
print(result.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     LY   R-squared (uncentered):                   0.995
# Model:                            OLS   Adj. R-squared (uncentered):              0.993
# Method:                 Least Squares   F-statistic:                              599.7
# Date:                Fri, 12 May 2023   Prob (F-statistic):                    2.02e-39
# Time:                        19:57:28   Log-Likelihood:                         -71.738
# No. Observations:                  50   AIC:                                      167.5
# Df Residuals:                      38   BIC:                                      190.4
# Df Model:                          12
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0277      0.020      1.393      0.172      -0.013       0.068
# x2            -0.0027      0.001     -2.164      0.037      -0.005      -0.000
# x3             0.0158      0.015      1.082      0.286      -0.014       0.045
# x4          5.247e-05   2.99e-05      1.753      0.088   -8.14e-06       0.000
# x5         -1.747e-05   2.78e-05     -0.629      0.533   -7.37e-05    3.88e-05
# x6         -1.385e-05   2.55e-05     -0.542      0.591   -6.56e-05    3.79e-05
# x7          5.787e-05   1.57e-05      3.688      0.001    2.61e-05    8.96e-05
# x8         -1.747e-05   2.78e-05     -0.629      0.533   -7.37e-05    3.88e-05
# x9            -0.0004      0.000     -3.557      0.001      -0.001      -0.000
# x10         1.098e-05   4.54e-06      2.419      0.020    1.79e-06    2.02e-05
# x11         3.362e-05   3.52e-05      0.955      0.346   -3.76e-05       0.000
# x12         2.694e-06    4.3e-06      0.627      0.535   -6.01e-06    1.14e-05
# x13            0.0003      0.000      1.962      0.057   -9.45e-06       0.001
# ==============================================================================
# Omnibus:                        2.446   Durbin-Watson:                   1.182
# Prob(Omnibus):                  0.294   Jarque-Bera (JB):                2.204
# Skew:                          -0.505   Prob(JB):                        0.332
# Kurtosis:                       2.803   Cond. No.                     8.04e+17
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The smallest eigenvalue is 4.28e-23. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
import numpy as np

def MPE(actual, pred): 
    actual, pred = np.array(actual), np.array(pred)
    return np.sum((actual - pred) / actual) * 100

# %%
MPE(y_test,testPredict)
# Out:
# 0.6686124018376028

# %%
MPE(y_train,trainPredict)
# Out:
# -0.0035516014848355182
